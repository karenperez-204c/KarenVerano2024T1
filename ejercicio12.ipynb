# %%
import CodeBase.sort_clases_fa as SC
import CodeBase.frec_acum as FA
import CodeBase.ordenar_asc as OR
import CodeBase.frec_rel as FR
import CodeBase.frec_abs as F
import CodeBase.tabla as T
import CodeBase.format_str as FS
import CodeBase.clases_str_sort as CSS
import CodeBase.clases_grouped as CG
import CodeBase.tabla_grouped as TG
import CodeBase.fa_grouped as FG

import Graficas.plot_grafOjiva as GO
import Graficas.plot_hist as GRH

# %%
#Ejercicio 12

datos_entrada2 = [250, 300, 440, 390, 410, 790, 750, 770, 380, 470, 580, 400, 510, 740, 500, 330, 420, 540, 340, 360, 270, 460, 510, 530, 530, 630, 260, 330, 260, 330]

clases2, lim_inf2, lim_sup2, mrks2 = CG.clases_grouped(datos_entrada2)
print("\n")
print("Clases: ", clases2)
print("Límites inferiores: ", lim_inf2)
print("Límites superiores: ", lim_sup2)
print("Marcas: ", mrks2)
print("\n")

datos = CSS.clases_str_sort(datos_entrada2)
print(datos)

fa2 = FG.fa_grouped(lim_inf2, lim_sup2, datos_entrada2)
print("Frecuencias Absolutas: ", fa2)

fr2 = FR.frec_rel(fa2)
print("Frecuencias Relativas: ", fr2)

facum2 = FA.frec_acum(fr2)
print("Frecuencias Acumuladas: ", facum2)
print("\n")

TG.tabla_grouped(clases2, lim_inf2, lim_sup2, mrks2, fa2, fr2, facum2)

GO.plot_grafOjiva(mrks2, facum2)
GRH.plot_hist(clases2, mrks2, fa2)
# Out:
# Clases:  [1, 2, 3, 4, 5, 6]
# Límites inferiores:  [250, 340.0, 430.0, 520.0, 610.0, 700.0]
# Límites superiores:  [340.0, 430.0, 520.0, 610.0, 700.0, 790]
# Marcas:  [295.0, 385.0, 475.0, 565.0, 655.0, 745.0]
#
#
# [250, 260, 260, 270, 300, 330, 330, 330, 340, 360, 380, 390, 400, 410, 420, 440, 460, 470, 500, 510, 510, 530, 530, 540, 580, 630, 740, 750, 770, 790]
# Frecuencias Absolutas:  [8, 7, 6, 4, 1, 3]
# Frecuencias Relativas:  [27.586206896551722, 24.137931034482758, 20.689655172413794, 13.793103448275861, 3.4482758620689653, 10.344827586206897]
# Frecuencias Acumuladas:  [27.586206896551722, 51.72413793103448, 72.41379310344827, 86.20689655172413, 89.6551724137931, 100.0]
#
#
#   Clase         Limite Inferior           Limite Superior         Marca de clase    Frecuencia Absoluta     Frecuencia Relativa      Frecuencia Acumulada
# ---------- ------------------------- ----------------------- ----------------- ----------------- ----------------------- -----------------------
# ...
